# %% [markdown]
# !pip install bs4 requests

# %%
wiki='https://en.wikipedia.org/wiki/List_of_state_and_union_territory_capitals_in_India'
url = "http://funkacer.pythonanywhere.com"

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
response = requests.get(wiki)

# %%
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'date': 'Fri, 08 Aug 2025 19:23:16 GMT', 'server': 'ATS/9.2.11', 'x-content-type-options': 'nosniff', 'content-language': 'en', 'accept-ch': '', 'last-modified': 'Tue, 05 Aug 2025 04:18:51 GMT', 'content-type': 'text/html; charset=UTF-8', 'content-encoding': 'gzip', 'age': '200', 'accept-ranges': 'bytes', 'vary': 'Accept-Encoding,X-Subdomain,Cookie,Authorization', 'x-cache': 'cp6015 hit, cp6011 hit/1', 'x-cache-status': 'hit-front', 'server-timing': 'cache;desc="hit-front", host;desc="cp6011"', 'strict-transport-security': 'max-age=106384710; includeSubDomains; preload', 'report-to': '{ "group": "wm_nel", "max_age": 604800, "endpoints": [{ "url": "https://intake-logging.wikimedia.org/v1/events?stream=w3c.reportingapi.network_error&schema_uri=/w3c/reportingapi/network_error/1.0.0" }] }', 'nel': '{ "report_to": "wm_nel", "max_age": 604800, "failure_fraction": 0.05, "success_fraction": 0.0}', 'set-cookie': 'WMF-Last-Access=08-Aug-2025;Path=/;HttpOnly;secure;Expires=Tue, 09 Sep 2025 12:
# ...

# %%
response.headers['content-type']
# Out:
# 'text/html; charset=UTF-8'

# %%
response.encoding
# Out:
# 'UTF-8'

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of state and union territory capitals in India - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feat
# ...

# %%
response.content
# Out:
# b'<!DOCTYPE html>\n<html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8">\n<title>List of state and union territory capitals in India - Wikipedia</title>\n<script>(function(){var className="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-fea
# ...

# %%
soup=BeautifulSoup(response.content)

# %%
soup
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of state and union territory capitals in India - Wikipedia</title>
# ...

# %%
soup.title
# Out:
# <title>List of state and union territory capitals in India - Wikipedia</title>

# %%
soup.title.text
# Out:
# 'List of state and union territory capitals in India - Wikipedia'

# %%
atags=soup.findAll("a")
# Out:
# /var/folders/fb/xl0hnskx527bfqkv38l3sn7h0000gn/T/ipykernel_16797/3455995651.py:1: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   atags=soup.findAll("a")

# %%
atags
# Out:
# [<a class="mw-jump-link" href="#bodyContent">Jump to content</a>,
#  <a accesskey="z" href="/wiki/Main_Page" title="Visit the main page [z]"><span>Main page</span></a>,
#  <a href="/wiki/Wikipedia:Contents" title="Guides to browsing Wikipedia"><span>Contents</span></a>,
#  <a href="/wiki/Portal:Current_events" title="Articles related to current events"><span>Current events</span></a>,
#  <a accesskey="x" href="/wiki/Special:Random" title="Visit a randomly selected article [x]"><span>Random article</span></a>,
#  <a href="/wiki/Wikipedia:About" title="Learn about Wikipedia and how it works"><span>About Wikipedia</span></a>,
#  <a href="//en.wikipedia.org/wiki/Wikipedia:Contact_us" title="How to contact Wikipedia"><span>Contact us</span></a>,
#  <a href="/wiki/Help:Contents" title="Guidance on how to use and edit Wikipedia"><span>Help</span></a>,
#  <a href="/wiki/Help:Introduction" title="Learn how to edit Wikipedia"><span>Learn to edit</span></a>,
# ...

# %%
htags=soup.findAll("h1")
# Out:
# /var/folders/fb/xl0hnskx527bfqkv38l3sn7h0000gn/T/ipykernel_16797/3967749167.py:1: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   htags=soup.findAll("h1")

# %%
htags
# Out:
# [<h1 class="firstHeading mw-first-heading" id="firstHeading"><span class="mw-page-title-main">List of state and union territory capitals in India</span></h1>]

# %%
ttags=soup.findAll("title")
# Out:
# /var/folders/fb/xl0hnskx527bfqkv38l3sn7h0000gn/T/ipykernel_16797/2601051093.py:1: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   ttags=soup.findAll("title")

# %%
ttags
# Out:
# [<title>List of state and union territory capitals in India - Wikipedia</title>]

# %%
stags=soup.findAll("style")
# Out:
# /var/folders/fb/xl0hnskx527bfqkv38l3sn7h0000gn/T/ipykernel_16797/632566860.py:1: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   stags=soup.findAll("style")

# %%
stags
# Out:
# [<style data-mw-deduplicate="TemplateStyles:r1129693374">.mw-parser-output .hlist dl,.mw-parser-output .hlist ol,.mw-parser-output .hlist ul{margin:0;padding:0}.mw-parser-output .hlist dd,.mw-parser-output .hlist dt,.mw-parser-output .hlist li{margin:0;display:inline}.mw-parser-output .hlist.inline,.mw-parser-output .hlist.inline dl,.mw-parser-output .hlist.inline ol,.mw-parser-output .hlist.inline ul,.mw-parser-output .hlist dl dl,.mw-parser-output .hlist dl ol,.mw-parser-output .hlist dl ul,.mw-parser-output .hlist ol dl,.mw-parser-output .hlist ol ol,.mw-parser-output .hlist ol ul,.mw-parser-output .hlist ul dl,.mw-parser-output .hlist ul ol,.mw-parser-output .hlist ul ul{display:inline}.mw-parser-output .hlist .mw-empty-li{display:none}.mw-parser-output .hlist dt::after{content:": "}.mw-parser-output .hlist dd::after,.mw-parser-output .hlist li::after{content:" · ";font-weight:bold}.mw-parser-output .hlist dd:last-child::after,.mw-parser-output .hlist dt:last-child::after,.mw-par
# ...

# %%
for link in atags:
    print(link.get('href'))
# Out:
# #bodyContent
# /wiki/Main_Page
# /wiki/Wikipedia:Contents
# /wiki/Portal:Current_events
# /wiki/Special:Random
# /wiki/Wikipedia:About
# //en.wikipedia.org/wiki/Wikipedia:Contact_us
# /wiki/Help:Contents
# /wiki/Help:Introduction
# /wiki/Wikipedia:Community_portal
# /wiki/Special:RecentChanges
# /wiki/Wikipedia:File_upload_wizard
# /wiki/Special:SpecialPages
# /wiki/Main_Page
# /wiki/Special:Search
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=List+of+state+and+union+territory+capitals+in+India
# /w/index.php?title=Special:UserLogin&returnto=List+of+state+and+union+territory+capitals+in+India
# https://donate.wikimedia.org/?wmf_source=donate&wmf_medium=sidebar&wmf_campaign=en.wikipedia.org&uselang=en
# /w/index.php?title=Special:CreateAccount&returnto=List+of+state+and+union+territory+capitals+in+India
# ...

# %% [markdown]
# url = "http://funkacer.pythonanywhere.com/table.html"
# response = requests.get(url)
# soup = BeautifulSoup(response.content)

# %%
tables = soup.findAll("table")
# Out:
# /var/folders/fb/xl0hnskx527bfqkv38l3sn7h0000gn/T/ipykernel_16797/4178004404.py:1: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   tables = soup.findAll("table")

# %%
tables
# Out:
# [<table class="sidebar nomobile nowraplinks"><tbody><tr><th class="sidebar-title"><a href="/wiki/States_and_union_territories_of_India" title="States and union territories of India">States and union <br/> territories of India</a> <br/> ordered by</th></tr><tr><td class="sidebar-image"><figure class="mw-halign-center" typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Flag_of_India.svg"><img class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="47" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/120px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/250px-Flag_of_India.svg.png 2x" width="70"/></a><figcaption></figcaption></figure></td></tr><tr><td class="sidebar-content hlist">
#  <ul><li><a href="/wiki/List_of_states_and_union_territories_of_India_by_area" title="List of states and union territories of India by area">Area</a></li>
# ...

# %%
wiki_tables = soup.find('table',{'class':'wikitable sortable plainrowheaders'})

# %%
wiki_tables

# %%
wiki_tables = soup.find("table")

# %%
wiki_tables
# Out:
# <table class="sidebar nomobile nowraplinks"><tbody><tr><th class="sidebar-title"><a href="/wiki/States_and_union_territories_of_India" title="States and union territories of India">States and union <br/> territories of India</a> <br/> ordered by</th></tr><tr><td class="sidebar-image"><figure class="mw-halign-center" typeof="mw:File"><a class="mw-file-description" href="/wiki/File:Flag_of_India.svg"><img class="mw-file-element" data-file-height="600" data-file-width="900" decoding="async" height="47" src="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/120px-Flag_of_India.svg.png" srcset="//upload.wikimedia.org/wikipedia/en/thumb/4/41/Flag_of_India.svg/250px-Flag_of_India.svg.png 2x" width="70"/></a><figcaption></figcaption></figure></td></tr><tr><td class="sidebar-content hlist">
# <ul><li><a href="/wiki/List_of_states_and_union_territories_of_India_by_area" title="List of states and union territories of India by area">Area</a></li>
# ...

# %%
allOceans = {}
for row in wiki_tables.find_all('tr'):
    cells=[c.find(text=True).strip() for c in row.findAll('td') if c.find(text=True)]
    names = [c.find(text=True).strip() for c in row.findAll('th')]
    #print(len(cells), cells, names)
    if len(cells)==3:
        ocean = cells[0]
        depth = cells[1]
        size = cells[2]
        print("{} (depth:({}, sixe: {})".format(ocean, depth, size))
        allOceans.update({ocean:{'depth':depth,"size":size}})
# Out:
# /var/folders/fb/xl0hnskx527bfqkv38l3sn7h0000gn/T/ipykernel_16797/691428489.py:3: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   cells=[c.find(text=True).strip() for c in row.findAll('td') if c.find(text=True)]
# /var/folders/fb/xl0hnskx527bfqkv38l3sn7h0000gn/T/ipykernel_16797/691428489.py:4: DeprecationWarning: Call to deprecated method findAll. (Replaced by find_all) -- Deprecated since version 4.0.0.
#   names = [c.find(text=True).strip() for c in row.findAll('th')]
# /var/folders/fb/xl0hnskx527bfqkv38l3sn7h0000gn/T/ipykernel_16797/691428489.py:4: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   names = [c.find(text=True).strip() for c in row.findAll('th')]
# /var/folders/fb/xl0hnskx527bfqkv38l3sn7h0000gn/T/ipykernel_16797/691428489.py:3: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
# ...

# %%
allOceans
# Out:
# {}

# %%
url_gopas = "https://funkacer.cz/gopas/"

# %%
response = requests.get(url_gopas)

# %%
json = response.json()

# %%
json['1']
# Out:
# {'Column1': 1,
#  'mpg': 18,
#  'cyl': 8,
#  'displacement': 307,
#  'horsepower': 130,
#  'weight': 3504,
#  'acceleration': 12,
#  'model_year': 70,
#  'origin': 'usa',
#  'name': 'chevrolet chevelle malibu',
#  'mfr': 'chevrolet'}
